# %%
top_10_CO2_countries = [
    "China",
    "United States",
    "India",
    "Russia",
    "Japan",
    "Iran",
    "Indonesia",
    "Saudi Arabia",
    "South Korea",
    "Germany",
]

# %%
len(top_10_CO2_countries)
