# %%
import pooch
POOCH = pooch.create(
    path=pooch.os_cache("noaa-data"),
    # Use the figshare DOI
    base_url="doi:10.5281/zenodo.5553029/",
    registry={
        "HEADERS.txt": "md5:2a306ca225fe3ccb72a98953ded2f536",
        "CRND0103-2016-NY_Millbrook_3_W.txt": "md5:eb69811d14d0573ffa69f70dd9c768d9",
        "CRND0103-2017-NY_Millbrook_3_W.txt": "md5:b911da727ba1bdf26a34a775f25d1088",
        "CRND0103-2018-NY_Millbrook_3_W.txt": "md5:5b61bc687261596eba83801d7080dc56",
        "CRND0103-2019-NY_Millbrook_3_W.txt": "md5:9b814430612cd8a770b72020ca4f2b7d",
        "CRND0103-2020-NY_Millbrook_3_W.txt": "md5:cd8de6d5445024ce35fcaafa9b0e7b64"
    },
)


import pandas as pd

with open(POOCH.fetch("HEADERS.txt")) as fp:
    data = fp.read()
lines = data.split('\n')
headers = lines[1].split(' ')

dframes = []
for year in range(2016, 2019):
    fname = f'CRND0103-{year}-NY_Millbrook_3_W.txt'               
    df = pd.read_csv(POOCH.fetch(fname), parse_dates=[1],
                     names=headers, header=None, sep='\s+',
                     na_values=[-9999.0, -99.0])
    dframes.append(df)

df = pd.concat(dframes)
df = df.set_index('LST_DATE')
df

#########################################################
#### BELOW ARE THE VARIABLES YOU SHOULD USE IN THE PLOTS!
#### (numpy arrays)  
#### NO PANDAS ALLOWED!
#########################################################

t_daily_min = df.T_DAILY_MIN.values
t_daily_max = df.T_DAILY_MAX.values
t_daily_mean = df.T_DAILY_MEAN.values
p_daily_calc = df.P_DAILY_CALC.values
soil_moisture_5 = df.SOIL_MOISTURE_5_DAILY.values
soil_moisture_10 = df.SOIL_MOISTURE_10_DAILY.values
soil_moisture_20 = df.SOIL_MOISTURE_20_DAILY.values
soil_moisture_50 = df.SOIL_MOISTURE_50_DAILY.values
soil_moisture_100 = df.SOIL_MOISTURE_100_DAILY.values
date = df.index.values
# Out:
# Downloading file 'HEADERS.txt' from 'doi:10.5281/zenodo.5553029/HEADERS.txt' to '/home/emf2229/.cache/noaa-data'.
# Downloading file 'CRND0103-2016-NY_Millbrook_3_W.txt' from 'doi:10.5281/zenodo.5553029/CRND0103-2016-NY_Millbrook_3_W.txt' to '/home/emf2229/.cache/noaa-data'.
# Downloading file 'CRND0103-2017-NY_Millbrook_3_W.txt' from 'doi:10.5281/zenodo.5553029/CRND0103-2017-NY_Millbrook_3_W.txt' to '/home/emf2229/.cache/noaa-data'.
# Downloading file 'CRND0103-2018-NY_Millbrook_3_W.txt' from 'doi:10.5281/zenodo.5553029/CRND0103-2018-NY_Millbrook_3_W.txt' to '/home/emf2229/.cache/noaa-data'.

# %%
units = lines[2].split(' ')
for name, unit in zip(headers, units):
    print(f'{name}: {unit}')
# Out:
# WBANNO: XXXXX
# LST_DATE: YYYYMMDD
# CRX_VN: XXXXXX
# LONGITUDE: Decimal_degrees
# LATITUDE: Decimal_degrees
# T_DAILY_MAX: Celsius
# T_DAILY_MIN: Celsius
# T_DAILY_MEAN: Celsius
# T_DAILY_AVG: Celsius
# P_DAILY_CALC: mm
# SOLARAD_DAILY: MJ/m^2
# SUR_TEMP_DAILY_TYPE: X
# SUR_TEMP_DAILY_MAX: Celsius
# SUR_TEMP_DAILY_MIN: Celsius
# SUR_TEMP_DAILY_AVG: Celsius
# RH_DAILY_MAX: %
# RH_DAILY_MIN: %
# RH_DAILY_AVG: %
# SOIL_MOISTURE_5_DAILY: m^3/m^3
# SOIL_MOISTURE_10_DAILY: m^3/m^3
# SOIL_MOISTURE_20_DAILY: m^3/m^3
# SOIL_MOISTURE_50_DAILY: m^3/m^3
# SOIL_MOISTURE_100_DAILY: m^3/m^3
# SOIL_TEMP_5_DAILY: Celsius
# SOIL_TEMP_10_DAILY: Celsius
# SOIL_TEMP_20_DAILY: Celsius
# SOIL_TEMP_50_DAILY: Celsius
# SOIL_TEMP_100_DAILY: Celsius
# :

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)

axes[0].fill_between(date, t_daily_min, t_daily_max, color='lightgray', label='daily range')
axes[0].plot(date, t_daily_mean, color='purple', linewidth=2, label='daily mean')
axes[0].set_ylabel('Temperature (°C)')
axes[0].legend(loc='upper right')

axes[1].bar(date, p_daily_calc, color='C0')
axes[1].set_ylabel('Precipitation (mm/day)')

axes[2].plot(date, soil_moisture_5, label='5 cm')
axes[2].plot(date, soil_moisture_10, label='10 cm')
axes[2].plot(date, soil_moisture_20, label='20 cm')
axes[2].plot(date, soil_moisture_50, label='50 cm')
axes[2].plot(date, soil_moisture_100, label='100 cm')
axes[2].set_ylabel('Soil Moisture (m³ / m³)')
axes[2].set_xlabel('Date')
axes[2].legend(loc='lower left')

for ax in axes:
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import xarray as xr

ds_url = 'http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods'

ds = xr.open_dataset(ds_url, decode_times=False, engine="pydap")

temp = ds.temp[-1].values - 273.15
lon = ds.X.values
lat = ds.Y.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       1 import xarray as xr
#       3 ds_url = 'http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods'
# ----> 5 ds = xr.open_dataset(ds_url, decode_times=False, engine="pydap")
#       7 temp = ds.temp[-1].values - 273.15
#       8 lon = ds.X.values
#
# File /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages/xarray/backends/api.py:582, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     579 if from_array_kwargs is None:
#     580     from_array_kwargs = {}
# --> 582 backend = plugins.get_backend(engine)
#     584 decoders = _resolve_decoders_kwargs(
#     585     decode_cf,
#     586     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    592     decode_coords=decode_coords,
#     593 )
#     595 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#
# File /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages/xarray/backends/plugins.py:220, in get_backend(engine)
#     218     engines = list_engines()
#     219     if engine not in engines:
# --> 220         raise ValueError(
#     221             f"unrecognized engine '{engine}' must be one of your download engines: {list(engines)}. "
#     222             "To install additional dependencies, see:\n"
#     223             "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     224             "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     225         )
#     226     backend = engines[engine]
#     227 elif issubclass(engine, BackendEntrypoint):
#
# ValueError: unrecognized engine 'pydap' must be one of your download engines: ['scipy', 'store']. To install additional dependencies, see:
# https://docs.xarray.dev/en/stable/user-guide/io.html
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html

# %%
# !pip install pydap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydap
#   Downloading pydap-3.5.8-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 25.8 MB/s eta 0:00:0000:0100:01
# Collecting Webob
#   Downloading WebOb-1.8.9-py2.py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.4/115.4 KB 6.9 MB/s eta 0:00:00
# Collecting requests-cache
#   Downloading requests_cache-1.3.1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 KB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from pydap) (1.21.5)
# Requirement already satisfied: beautifulsoup4 in /usr/lib/python3/dist-packages (from pydap) (4.10.0)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from pydap) (1.8.0)
# Requirement already satisfied: lxml in /usr/lib/python3/dist-packages (from pydap) (4.8.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from pydap) (2.25.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/emf2229/.local/lib/python3.10/site-packages (from requests-cache->pydap) (4.9.2)
# Collecting url-normalize>=2.0
#   Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: attrs>=21.2 in /usr/lib/python3/dist-packages (from requests-cache->pydap) (21.2.0)
# Collecting cattrs>=22.2
#   Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.25.5 in /usr/lib/python3/dist-packages (from requests-cache->pydap) (1.26.5)
# Collecting exceptiongroup>=1.1.1
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting attrs>=21.2
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 KB 8.2 MB/s eta 0:00:00
# Collecting typing-extensions>=4.14.0
#   Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: idna>=3.3 in /usr/lib/python3/dist-packages (from url-normalize>=2.0->requests-cache->pydap) (3.3)
# Installing collected packages: Webob, url-normalize, typing-extensions, attrs, exceptiongroup, cattrs, requests-cache, pydap
#   WARNING: The script url-normalize is installed in '/home/emf2229/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dods and pydap are installed in '/home/emf2229/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Webob-1.8.9 attrs-25.4.0 cattrs-26.1.0 exceptiongroup-1.3.1 pydap-3.5.8 requests-cache-1.3.1 typing-extensions-4.15.0 url-normalize-2.2.1

# %%
temp = ds.temp[-1].values - 273.15
lon = ds.X.values
lat = ds.Y.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 temp = ds.temp[-1].values - 273.15
#       2 lon = ds.X.values
#       3 lat = ds.Y.values
#
# NameError: name 'ds' is not defined

# %%
import xarray as xr

ds_url = "http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods"

ds = xr.open_dataset(ds_url, decode_times=False, engine="pydap")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 import xarray as xr
#       3 ds_url = "http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods"
# ----> 5 ds = xr.open_dataset(ds_url, decode_times=False, engine="pydap")
#
# File /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages/xarray/backends/api.py:582, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     579 if from_array_kwargs is None:
#     580     from_array_kwargs = {}
# --> 582 backend = plugins.get_backend(engine)
#     584 decoders = _resolve_decoders_kwargs(
#     585     decode_cf,
#     586     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    592     decode_coords=decode_coords,
#     593 )
#     595 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#
# File /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages/xarray/backends/plugins.py:220, in get_backend(engine)
#     218     engines = list_engines()
#     219     if engine not in engines:
# --> 220         raise ValueError(
#     221             f"unrecognized engine '{engine}' must be one of your download engines: {list(engines)}. "
#     222             "To install additional dependencies, see:\n"
#     223             "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     224             "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     225         )
#     226     backend = engines[engine]
#     227 elif issubclass(engine, BackendEntrypoint):
#
# ValueError: unrecognized engine 'pydap' must be one of your download engines: ['scipy', 'store']. To install additional dependencies, see:
# https://docs.xarray.dev/en/stable/user-guide/io.html
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html

# %%
# !pip install pydap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydap in /home/emf2229/.local/lib/python3.10/site-packages (3.5.8)
# Requirement already satisfied: lxml in /usr/lib/python3/dist-packages (from pydap) (4.8.0)
# Requirement already satisfied: beautifulsoup4 in /usr/lib/python3/dist-packages (from pydap) (4.10.0)
# Requirement already satisfied: Webob in /home/emf2229/.local/lib/python3.10/site-packages (from pydap) (1.8.9)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from pydap) (2.25.1)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from pydap) (1.8.0)
# Requirement already satisfied: requests-cache in /home/emf2229/.local/lib/python3.10/site-packages (from pydap) (1.3.1)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from pydap) (1.21.5)
# Requirement already satisfied: attrs>=21.2 in /home/emf2229/.local/lib/python3.10/site-packages (from requests-cache->pydap) (25.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/emf2229/.local/lib/python3.10/site-packages (from requests-cache->pydap) (4.9.2)
# Requirement already satisfied: url-normalize>=2.0 in /home/emf2229/.local/lib/python3.10/site-packages (from requests-cache->pydap) (2.2.1)
# Requirement already satisfied: cattrs>=22.2 in /home/emf2229/.local/lib/python3.10/site-packages (from requests-cache->pydap) (26.1.0)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/lib/python3/dist-packages (from requests-cache->pydap) (1.26.5)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /home/emf2229/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache->pydap) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in /home/emf2229/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache->pydap) (4.15.0)
# Requirement already satisfied: idna>=3.3 in /usr/lib/python3/dist-packages (from url-normalize>=2.0->requests-cache->pydap) (3.3)

# %%
import xarray as xr

ds_url = "http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods"
ds = xr.open_dataset(ds_url, decode_times=False, engine="pydap")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 import xarray as xr
#       3 ds_url = "http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods"
# ----> 4 ds = xr.open_dataset(ds_url, decode_times=False, engine="pydap")
#
# File /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages/xarray/backends/api.py:582, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     579 if from_array_kwargs is None:
#     580     from_array_kwargs = {}
# --> 582 backend = plugins.get_backend(engine)
#     584 decoders = _resolve_decoders_kwargs(
#     585     decode_cf,
#     586     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    592     decode_coords=decode_coords,
#     593 )
#     595 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#
# File /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages/xarray/backends/plugins.py:220, in get_backend(engine)
#     218     engines = list_engines()
#     219     if engine not in engines:
# --> 220         raise ValueError(
#     221             f"unrecognized engine '{engine}' must be one of your download engines: {list(engines)}. "
#     222             "To install additional dependencies, see:\n"
#     223             "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     224             "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     225         )
#     226     backend = engines[engine]
#     227 elif issubclass(engine, BackendEntrypoint):
#
# ValueError: unrecognized engine 'pydap' must be one of your download engines: ['scipy', 'store']. To install additional dependencies, see:
# https://docs.xarray.dev/en/stable/user-guide/io.html
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html

# %%
import sys
# !{sys.executable} -m pip install pydap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydap
#   Downloading pydap-3.5.8-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (1.26.4)
# Requirement already satisfied: requests in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (2.32.5)
# Collecting requests-cache (from pydap)
#   Downloading requests_cache-1.3.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: scipy in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (1.16.0)
# Collecting Webob (from pydap)
#   Downloading WebOb-1.8.9-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (4.14.2)
# Requirement already satisfied: lxml in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (5.2.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from beautifulsoup4->pydap) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from beautifulsoup4->pydap) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests-cache->pydap) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests-cache->pydap) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests-cache->pydap) (4.5.0)
# Collecting url-normalize>=2.0 (from requests-cache->pydap)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading pydap-3.5.8-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 31.2 MB/s  0:00:00
# Downloading requests_cache-1.3.1-py3-none-any.whl (70 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading WebOb-1.8.9-py2.py3-none-any.whl (115 kB)
# Installing collected packages: Webob, url-normalize, requests-cache, pydap
#   WARNING: The script url-normalize is installed in '/home/emf2229/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [pydap]ts-cache]  WARNING: The scripts dods and pydap are installed in '/home/emf2229/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pydap]
# Successfully installed Webob-1.8.9 pydap-3.5.8 requests-cache-1.3.1 url-normalize-2.2.1

# %%
import xarray as xr
print(xr.backends.list_engines())
# Out:
# {'scipy': <ScipyBackendEntrypoint>
#   Open netCDF files (.nc, .nc4, .cdf and .gz) using scipy in Xarray
#   Learn more at https://docs.xarray.dev/en/stable/generated/xarray.backends.ScipyBackendEntrypoint.html, 'store': <StoreBackendEntrypoint>
#   Open AbstractDataStore instances in Xarray
#   Learn more at https://docs.xarray.dev/en/stable/generated/xarray.backends.StoreBackendEntrypoint.html}

# %%
import sys
# !{sys.executable} -m pip install pydap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydap in /home/emf2229/.local/lib/python3.11/site-packages (3.5.8)
# Requirement already satisfied: numpy in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (1.26.4)
# Requirement already satisfied: requests in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (2.32.5)
# Requirement already satisfied: requests-cache in /home/emf2229/.local/lib/python3.11/site-packages (from pydap) (1.3.1)
# Requirement already satisfied: scipy in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (1.16.0)
# Requirement already satisfied: Webob in /home/emf2229/.local/lib/python3.11/site-packages (from pydap) (1.8.9)
# Requirement already satisfied: beautifulsoup4 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (4.14.2)
# Requirement already satisfied: lxml in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pydap) (5.2.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from beautifulsoup4->pydap) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from beautifulsoup4->pydap) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests->pydap) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests-cache->pydap) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests-cache->pydap) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests-cache->pydap) (4.5.0)
# Requirement already satisfied: url-normalize>=2.0 in /home/emf2229/.local/lib/python3.11/site-packages (from requests-cache->pydap) (2.2.1)

# %%
import xarray as xr

ds_url = "http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods"

ds = xr.open_dataset(ds_url, decode_times=False)
# Out:
# /home/emf2229/.local/lib/python3.11/site-packages/pydap/handlers/dap.py:143: UserWarning: PyDAP was unable to determine the DAP protocol defaulting to DAP2. DAP2 is consider legacy and may result in slower responses.
# Consider replacing `http` in your `url` with either `dap2` or `dap4` to specify the DAP protocol (e.g. `dap2://<data_url>` or `dap4://<data_url>`).  For more
# information, go to https://www.opendap.org/faq-page.
#   warnings.warn(

# %%
temp = ds.temp[-1].values - 273.15
lon = ds.X.values
lat = ds.Y.values

# %%
import matplotlib.pyplot as plt
import numpy as np

zonal_mean = np.mean(temp, axis=1)

levels = np.arange(-30, 41, 2.5)

fig, axes = plt.subplots(
    1, 2,
    figsize=(8, 4),
    gridspec_kw={'width_ratios': [4, 1]}
)

filled = axes[0].contourf(lon, lat, temp, levels=levels, cmap='magma', extend='both')

axes[0].contour(lon, lat, temp, levels=[-5], colors='white', linewidths=1.2, linestyles='solid')

axes[0].set_title('Current Global Temperature', fontsize=10)
axes[0].set_xlabel('Longitude')
axes[0].set_ylabel('Latitude')
axes[0].set_xlim(0, 360)
axes[0].set_ylim(-90, 90)
axes[0].grid(True, alpha=0.3)

cbar = plt.colorbar(filled, ax=axes[0], shrink=0.78, pad=0.04)
cbar.set_label('°C')
cbar.set_ticks(np.arange(-30, 41, 10))

axes[1].plot(zonal_mean, lat, color='black', linewidth=1.5)
axes[1].set_title('Zonal Mean Temperature', fontsize=10)
axes[1].set_xlabel('°C')
axes[1].set_xlim(-60, 40)
axes[1].set_ylim(-90, 90)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import pooch
import numpy as np

fname = pooch.retrieve(
    "https://rabernat.github.io/research_computing/signif.txt.tsv.zip",
    known_hash='22b9f7045bf90fb99e14b95b24c81da3c52a0b4c79acf95d72fbe3a257001dbb',
    processor=pooch.Unzip()
)[0]

earthquakes = np.genfromtxt(fname, delimiter='\t')

depth = earthquakes[:, 8]
magnitude = earthquakes[:, 9]
latitude = earthquakes[:, 20]
longitude = earthquakes[:, 21]
# Out:
# Downloading data from 'https://rabernat.github.io/research_computing/signif.txt.tsv.zip' to file '/home/emf2229/.cache/pooch/031a30a92d6a3a2680d86514a24e9321-signif.txt.tsv.zip'.
# Unzipping contents of '/home/emf2229/.cache/pooch/031a30a92d6a3a2680d86514a24e9321-signif.txt.tsv.zip' to '/home/emf2229/.cache/pooch/031a30a92d6a3a2680d86514a24e9321-signif.txt.tsv.zip.unzip'

# %%
import matplotlib.pyplot as plt
import numpy as np

log_depth = np.log10(depth + 1)

plt.figure(figsize=(10, 6))

sc = plt.scatter(longitude, latitude, c=log_depth, s=magnitude/100 * 80)

plt.title('Location of Significant Earthquakes With Size Indicating Relative Magnitude')
plt.xlabel('Longitude (°)')
plt.ylabel('Latitude (°)')
plt.grid(True, alpha=0.3)

cbar = plt.colorbar(sc)
cbar.set_label('Depth [m]')
cbar.set_ticks([0,1,2])
cbar.set_ticklabels([r'$10^0$', r'$10^1$', r'$10^2$'])

plt.show()
