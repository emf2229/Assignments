# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 0.5, 0.8])

# %%
fig = plt.figure()
ax1= fig.add_axes([0, 0, 0.5, 1], facecolor = 'lightgray')
ax2 = fig.add_axes([0.6, 0, 0.3, 1],projection = 'polar')

# %%
fig = plt.figure()
axes = fig.subplots(nrows=2,ncols=3)
