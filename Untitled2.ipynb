# %%
import xarray as xr
url = "http://iridl.ldeo.columbia.edu/expert/SOURCES/.NOAA/.NCEP/.CPC/.UNIFIED_PRCP/.GAUGE_BASED/.GLOBAL/.v1p0/.Monthly/.RETRO/.rain/dods"
# decode_times=False is required because the IRI Data Library uses non-standard encoding of times
ds = xr.open_dataset(url, decode_times=False)
ds
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/sw/anaconda3/2023.09/envs/pangeo23/share/proj failed
# <xarray.Dataset> Size: 336MB
# Dimensions:  (T: 324, Y: 360, X: 720)
# Coordinates:
#   * T        (T) float32 1kB 228.5 229.5 230.5 231.5 ... 548.5 549.5 550.5 551.5
#   * Y        (Y) float32 1kB -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * X        (X) float32 3kB 0.25 0.75 1.25 1.75 ... 358.2 358.8 359.2 359.8
# Data variables:
#     rain     (T, Y, X) float32 336MB ...
# Attributes:
#     Conventions:  IRIDL

# %%
ds.sel(Y=89.75, X-0.25)
# Out:
#   Cell In[2], line 1
#     ds.sel(Y=89.75, X-0.25)
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
ds.sel(Y=89.75, X=0.25)
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:  (T: 324)
# Coordinates:
#   * T        (T) float32 1kB 228.5 229.5 230.5 231.5 ... 548.5 549.5 550.5 551.5
#     Y        float32 4B 89.75
#     X        float32 4B 0.25
# Data variables:
#     rain     (T) float32 1kB ...
# Attributes:
#     Conventions:  IRIDL

# %%
# Out:
#   Cell In[4], line 1
#     ds.sel(T=slice(229.5, 300.5)
#                                 ^
# SyntaxError: incomplete input

# %%
ds.sel(T=slice(229.5, 300.5))
# Out:
# <xarray.Dataset> Size: 75MB
# Dimensions:  (T: 72, Y: 360, X: 720)
# Coordinates:
#   * T        (T) float32 288B 229.5 230.5 231.5 232.5 ... 298.5 299.5 300.5
#   * Y        (Y) float32 1kB -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * X        (X) float32 3kB 0.25 0.75 1.25 1.75 ... 358.2 358.8 359.2 359.8
# Data variables:
#     rain     (T, Y, X) float32 75MB ...
# Attributes:
#     Conventions:  IRIDL

# %%
ds_refined.to_netcdf("filtered_NETCDEF.nc")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds_refined.to_netcdf("filtered_NETCDEF.nc")
#
# NameError: name 'ds_refined' is not defined

# %%
ds_refined= ds.sel(X=slice(0.25, 0.75), Y=slice(-89.75, -86.0), T=slice(229.5, 300.5))

# %%
ds_refined
# Out:
# <xarray.Dataset> Size: 5kB
# Dimensions:  (T: 72, Y: 8, X: 2)
# Coordinates:
#   * T        (T) float32 288B 229.5 230.5 231.5 232.5 ... 298.5 299.5 300.5
#   * Y        (Y) float32 32B -89.75 -89.25 -88.75 ... -87.25 -86.75 -86.25
#   * X        (X) float32 8B 0.25 0.75
# Data variables:
#     rain     (T, Y, X) float32 5kB ...
# Attributes:
#     Conventions:  IRIDL

# %%
ds_refined.to_netcdf("filtered_NETCDEF.nc")

# %%
import pooch
POOCH = pooch.create(
    path=pooch.os_cache("2017_Antarctica_P3/CSARP_mvdr"),
    base_url="https://data.cresis.ku.edu/data/rds/2017_Antarctica_P3/CSARP_mvdr/20171124_03/",
    registry={
        "Data_img_02_20171124_03_020.mat": None,
    }
)

local_fname = POOCH.fetch("Data_img_02_20171124_03_020.mat")
local_fname
# Out:
# Downloading file 'Data_img_02_20171124_03_020.mat' from 'https://data.cresis.ku.edu/data/rds/2017_Antarctica_P3/CSARP_mvdr/20171124_03/Data_img_02_20171124_03_020.mat' to '/home/emf2229/.cache/2017_Antarctica_P3/CSARP_mvdr'.
# '/home/emf2229/.cache/2017_Antarctica_P3/CSARP_mvdr/Data_img_02_20171124_03_020.mat'

# %%
import hp5y
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import hp5y
#
# ModuleNotFoundError: No module named 'hp5y'

# %%
import h5py
f = h5py.File(local_fname)
f
# Out:
# <HDF5 file "Data_img_02_20171124_03_020.mat" (mode r)>

# %%
list(f)
# Out:
# ['#refs#',
#  'Bottom',
#  'Data',
#  'Elevation',
#  'GPS_time',
#  'Heading',
#  'Latitude',
#  'Longitude',
#  'Pitch',
#  'Roll',
#  'Surface',
#  'Time',
#  'param_combine',
#  'param_csarp',
#  'param_records']

# %%
POOCH = pooch.create(
    path=pooch.os_cache("greenland_ice_sheet"),
    base_url="https://zenodo.org/record/4977910/files/",
    registry={
        "vel_2010-07-01_2011-06-31.nc": "md5:80ad1a3c381af185069bc032a6459745",
    }
)

fname = POOCH.fetch("vel_2010-07-01_2011-06-31.nc")
fname
# Out:
# Downloading file 'vel_2010-07-01_2011-06-31.nc' from 'https://zenodo.org/record/4977910/files/vel_2010-07-01_2011-06-31.nc' to '/home/emf2229/.cache/greenland_ice_sheet'.
# '/home/emf2229/.cache/greenland_ice_sheet/vel_2010-07-01_2011-06-31.nc'
